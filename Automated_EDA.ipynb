# %%
### Automated EDA using ydata-profiling

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 5.4 MB/s  0:00:01m 5.2 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.5/682.5 kB 13.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.4 MB/s  0:00:0017.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 550.7/550.7 kB 19.5 MB/s  0:00:00
# ...
#   Attempting uninstall: matplotlib╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [multimethod]
#     Found existing installation: matplotlib 3.10.6━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [multimethod]
#     Uninstalling matplotlib-3.10.6:╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [multimethod]
#       Successfully uninstalled matplotlib-3.10.68;5;237m╺━━━━━━━━━━━━━━━━━━━  6/12 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [ydata-profiling] 11/12 [ydata-profiling]
# ...

# %%
import seaborn as sns 
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Data Profiling Report",explorative=True)

# 3. View the report directly inside your Jupyter Notebook
# profile.to_notebook_iframe()

# 4. Or save it as an external shareable HTML file
profile.to_file("data_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#####  Automated EDA with autoviz

# %%
pip install autoviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 2.0 MB/s  0:02:17 eta 0:00:010:00:04
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 9.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.1 MB/s  0:00:0024.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 7.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [autoviz]━━━━━━━━━━ 4/7 [pyamg]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = sns.load_dataset('cal')

df.to_csv("tips.csv")

# %%
from autoviz import AutoViz_Class
AV = AutoViz_Class()

# %%
import matplotlib.pyplot as plt
from autoviz import AutoViz_Class

# 1. Ensure plots display correctly inside your notebook environment
# %matplotlib inline

# 2. Instantiate the AutoViz engine object
AV = AutoViz_Class()

# 3. Define the file path string variable
filename = "california_housing_train.csv"

# 4. Generate the automated visualizations by passing required keyword arguments
dft = AV.AutoViz(
    filename=filename,  # Maps the path to the filename parameter
    # sep=",",  # Defines the delimiter used in the text file
    # depVar="median_house_value",  # Explicitly names your target column (or leave as '' if unsupervised)
    # dfte=None,  # Set to None since you are reading from a raw file path directly
    # header=0,  # Treats the first row as feature names
    # verbose=1,  # Displays full charts inside the notebook cell
)
# Out:
# Shape of your Data Set loaded: (17000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  9
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     9 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
### Automated EDA using sweetviz

# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 2.1 MB/s  0:00:07 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sweetviz]━━ 1/2 [sweetviz]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 titanic = sns.load_dataset("titanic")

# %%
import sweetviz as sv
my_report = sv.analyze(titanic)
my_report.show_html()
# Out:
#                                              |                                                                …
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# kf.service.services: KApplicationTrader: mimeType "x-scheme-handler/file" not found
# Opening in existing browser session.

# %%
### Automated EDA using D-tale

# %%
pip install dtale
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 2.4 MB/s  0:00:07m 2.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.0 MB/s  0:00:00 14.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.6 MB/s  0:00:00m 34.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [dtale]8;5;237m━━ 15/16 [dtale]p-components]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale
import pandas as pd


#Launch the interactive D-Tale GUI instance
# In a Jupyter notebook, this will render directly inline in the output cell
d_instance = dtale.show(titanic)
# 3. Explicitly open the interactive dashboard in a new web browser tab
d_instance.open_browser()
